# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, assemble, Aer
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex
from qiskit.visualization import state_visualization
from qiskit.visualization import plot_state_city, plot_bloch_multivector
import qis401, random, math, cmath

# %% [markdown]
# ###  Bloch Sphere from Single Qubit Circuit

# %%
circ = QuantumCircuit(1)  
circ.x(0)                
circ.h(0)
result = qis401.simulate_circuit(circ)
output_state = result.get_statevector()
output_state.draw(output='latex')
# Out:
# <class 'qiskit_aer.backends.compatibility.Statevector'>
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2}}{2} |1\rangle$$

# %%
plot_bloch_multivector(output_state)

# %%
# Problem 2.1
circ = QuantumCircuit(1)
circ.initialize([0.5, 1/np.sqrt(2)+0.5j], 0)
result = qis401.simulate_circuit(circ)
output_state = result.get_statevector()
output_state.draw(output='latex')
# Out:
# $$\frac{1}{2} |0\rangle+(\frac{\sqrt{2}}{2} + \frac{i}{2}) |1\rangle$$

# %%
# Problem 2.2
circ = QuantumCircuit(1)
circ.initialize([(np.sqrt(3)/2)*1j, 1/np.sqrt(8)+(1/np.sqrt(8))*1j], 0)
result = qis401.simulate_circuit(circ)
output_state = result.get_statevector()
output_state.draw(output='latex')
# Out:
# $$\frac{\sqrt{3} i}{2} |0\rangle+(\frac{\sqrt{2}}{4} + \frac{\sqrt{2} i}{4}) |1\rangle$$

# %%
circ = QuantumCircuit(1)
circ.initialize([0.5, 1/np.sqrt(2)+0.5j], 0)
# result = qis401.simulate_circuit(circ)
output_state = Statevector(circ)
plot_bloch_multivector(output_state)

# %%
plot_bloch_multivector(output_state)

# %% [markdown]
# ###  Bloch Spheres from Multiple Qubit Circuit with Final Unentangled State

# %%
a_reg = QuantumRegister(1, "a")      
b_reg = QuantumRegister(1, "b")
circ = QuantumCircuit(a_reg, b_reg)  
circ.h(a_reg)  
result = qis401.simulate_circuit(circ)
result.get_statevector().draw(output='latex')
output_state = result.get_statevector()
output_state.draw(output='latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |01\rangle$$

# %%
plot_bloch_multivector(output_state)

# %% [markdown]
# ###  Bloch Spheres from Multiple Qubit Circuit with Final Entangled State?

# %%
# circuit that creates an EPR pair
a_reg = QuantumRegister(1, "a")      
b_reg = QuantumRegister(1, "b")
circ = QuantumCircuit(a_reg, b_reg)  
circ.h(a_reg)                        
circ.cx(a_reg, b_reg)  
result = qis401.simulate_circuit(circ)
output_state = result.get_statevector()
output_state.draw(output='latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
plot_bloch_multivector(output_state)
